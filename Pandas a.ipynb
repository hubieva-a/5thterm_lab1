# %% [markdown]
# # Pandas

# %%
import pandas as pd
data = pd.read_csv('streamed.csv')

# %%
data
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %% [markdown]
# 1) Где дата релиза - 2020 год

# %%
data[data.year == 2020]
# Out:
#                            title      artist                  top genre  year  \
# 0                Blinding Lights  The Weeknd  canadian contemporary r&b  2020
# 19  ROCKSTAR (feat. Roddy Ricch)      DaBaby     north carolina hip hop  2020
# 43               Don't Start Now    Dua Lipa                  dance pop  2020
#
#     beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0                171      73            51           -6         9       33
# 19                90      69            75           -8        10       50
# 43               124      79            79           -5        10       68
#
#     length  acousticness  speechiness  popularity
# 0      200             0            6          91
# 19     182            25           16          84
# 43     183             1            8          81

# %% [markdown]
# 2) Посчитать по жанрам

# %%
data['top genre'].value_counts()
# Out:
# dance pop                    28
# pop                          11
# dfw rap                       7
# canadian pop                  6
# modern rock                   6
# canadian contemporary r&b     4
# electropop                    4
# melodic rap                   3
# rap                           2
# canadian hip hop              2
# emo rap                       2
# latin                         2
# folk-pop                      2
# pop dance                     1
# cali rap                      1
# conscious hip hop             1
# neo soul                      1
# acoustic pop                  1
# pop rap                       1
# gangster rap                  1
# classic rock                  1
# brostep                       1
# electro house                 1
# north carolina hip hop        1
# australian dance              1
# beatlesque                    1
# chicago rap                   1
# boy band                      1
# alternative rock              1
# ...

# %% [markdown]
# 3) Жанр и длина песни

# %%
data.groupby('top genre')['length'].value_counts()
# Out:
# top genre         length
# acoustic pop      242       1
# alternative rock  223       1
# australian dance  212       1
# australian pop    209       1
# beatlesque        259       1
#                            ..
# pop               282       1
# pop dance         172       1
# pop rap           258       1
# rap               244       1
#                   313       1
# Name: length, Length: 96, dtype: int64

# %% [markdown]
# 4) Название исполнителя и liveness

# %%
data[['title', 'liveness']].head(10)
# Out:
#                     title  liveness
# 0         Blinding Lights         9
# 1        Watermelon Sugar        34
# 2  Mood (feat. iann dior)        32
# 3       Someone You Loved        11
# 4                 Perfect        11
# 5                Believer         8
# 6    lovely (with Khalid)        10
# 7                 Circles         9
# 8            Shape of You         9
# 9                Memories         8

# %% [markdown]
# 5) Отсортировать по ритму песни

# %%
a = data.sort_values(by='beats.per.minute')
a.head()
# Out:
#                                   title        artist         top genre  year  \
# 44  Bohemian Rhapsody - Remastered 2011         Queen      classic rock  1975
# 22                                 SAD!  XXXTENTACION           emo rap  2018
# 89                           Let Her Go     Passenger          folk-pop  2013
# 42                           God's Plan         Drake  canadian hip hop  2018
# 29                    Thinking out Loud    Ed Sheeran               pop  2014
#
#     beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 44                71      40            41          -10        30       22
# 22                75      61            74           -5        12       47
# 89                76      54            45           -7        11       22
# 42                77      45            75           -9        55       36
# 29                79      45            78           -6        18       59
#
# ...
